# %%
import gzip
import json
import dateutil.parser
import random

# %%
import homework1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3996439661.py in <cell line: 0>()
# ----> 1 import homework1
#
# ModuleNotFoundError: No module named 'homework1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
root = "/content/gdrive/MyDrive/colab/datasets"

# %%
f = gzip.open(root + "/fantasy_10000.json.gz")
dataset = []
for l in f:
    dataset.append(json.loads(l))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3239958646.py in <cell line: 0>()
# ----> 1 f = gzip.open(root + "/fantasy_10000.json.gz")
#       2 dataset = []
#       3 for l in f:
#       4     dataset.append(json.loads(l))
#
# /usr/lib/python3.12/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      63     gz_mode = mode.replace("t", "")
#      64     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 65         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      66     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      67         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /usr/lib/python3.12/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     199         try:
#     200             if fileobj is None:
# --> 201                 fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     202             if filename is None:
#     203                 filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/colab/datasets/fantasy_10000.json.gz'

# %%
dataset[0]

# %%
for d in dataset:
    t = dateutil.parser.parse(d['date_added'])
    d['parsed_date'] = t

# %%
dataset[0]

# %%
dataset4 = dataset[:]
random.seed(0)
random.shuffle(dataset4)

# %%
f = open("/home/julian/Downloads/beer_50000.json")
datasetB = []
for l in f:
    datasetB.append(eval(l))

# %%
datasetB[0]

# %%
def testQ1():
    theta1, MSE1 = homework1.Q1(dataset)
    # The autograder will compare these answers to a reference solution
    print(theta1)
    print(MSE1)

# %%
def testQ2():
    X, Y, MSE = homework1.Q2(dataset)
    print((X[0],Y[0],MSE))

# %%
def testQ3():
    X, Y, MSE = homework1.Q3(dataset)
    print((X[0],Y[0],MSE))

# %%
def testQ4():
    test_mse2, test_mse3 = homework1.Q4(dataset4)
    print((test_mse2, test_mse3))

# %%
def testQ5():
    TP, TN, FP, FN, BER = homework1.Q5(datasetB, homework1.featureQ5)
    print((TP, TN, FP, FN, BER))

# %%
def testQ6():
    precs = homework1.Q6(datasetB)
    print(precs)

# %%
def testQ7():
    _, _, _, _, BER5 = homework1.Q5(datasetB, homework1.featureQ5)
    _, _, _, _, BER7 = homework1.Q5(datasetB, homework1.featureQ7)
    print((BER5,BER7))

# %%
testQ1()

# %%
testQ2()

# %%
testQ3()

# %%
testQ4()

# %%
testQ5()

# %%
testQ6()

# %%
testQ7()
